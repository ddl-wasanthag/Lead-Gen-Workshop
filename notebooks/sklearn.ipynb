# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
path = str('/mnt/data/{}/WineQualityData.csv'.format(os.environ.get('DOMINO_PROJECT_NAME')))
df = pd.read_csv(path)
df.head()
# Out:
#    id   type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   0  white            7.0              0.27         0.36            20.7
# 1   1  white            6.3              0.30         0.34             1.6
# 2   2  white            8.1              0.28         0.40             6.9
# 3   3  white            7.2              0.23         0.32             8.5
# 4   4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality  is_red
# 0       0.45      8.8     5.58       0
# 1       0.49      9.5     5.04       0
# 2       0.44     10.1     5.34       0
# 3       0.40      9.9     4.92       0
# 4       0.40      9.9     5.16       0

# %%
sns.histplot(df.quality)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Count'>

# %%
for col in df.columns:
    df.rename({col: col.replace(' ', '_')}, axis =1, inplace = True)

# %%
df['is_red'] = df.type.apply(lambda x : int(x=='red'))

# %%
df.type.value_counts()
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %%
df.is_red.value_counts()
# Out:
# 0    4898
# 1    1599
# Name: is_red, dtype: int64

# %%
na_values = df.isna().sum()
na_values = na_values[na_values>0]
na_values
# Out:
# fixed_acidity       10
# volatile_acidity     8
# citric_acid          3
# residual_sugar       2
# chlorides            2
# pH                   9
# sulphates            4
# dtype: int64

# %%
corr_values = df.corr().sort_values(by = 'quality')['quality'].drop('quality',axis=0)

# %%
important_feats=corr_values[abs(corr_values)>0.08]
important_feats
# Out:
# density            -0.234881
# volatile_acidity   -0.199486
# chlorides          -0.148369
# is_red             -0.080618
# alcohol             0.341581
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(10,4))
sns.barplot(important_feats.keys(), important_feats.values)
# Out:
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
sns.scatterplot(x=df.alcohol, y = df.quality, hue =df.type, style = df.type, size= df.alcohol, sizes=(10,50))
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
sns.jointplot(kind = 'hist', x=df.alcohol, y = df.quality, hue = df.type)

# %%
#Create combo chart
fig, ax1 = plt.subplots(figsize=(10,6))
color = 'tab:green'
#bar plot creation
ax1.set_title('Average Percipitation Percentage by Month', fontsize=16)
ax1.set_xlabel('Month', fontsize=16)
ax1.set_ylabel('Avg Temp', fontsize=16)
ax1 = sns.barplot(x=df.type, y=df.quality, palette='summer')
ax1.tick_params(axis='y')
#specify we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
#line plot creation
ax2.set_ylabel('Alcohol %', fontsize=16)
ax2 = sns.lineplot(x=df.type, y=df.alcohol, sort=False, color=color)
ax2.tick_params(axis='y', color=color)
#show plot
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
important_feats.keys()
# Out:
# Index(['density', 'volatile_acidity', 'chlorides', 'is_red', 'alcohol'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
df = df.dropna(how='any',axis=0)
X = df[important_feats.keys()]
# X = df.drop(['type','quality'], axis=1)
y = df['quality'].astype('float64')
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.22, random_state=42)

# %%
X.dtypes
# Out:
# density             float64
# volatile_acidity    float64
# chlorides           float64
# is_red                int64
# alcohol             float64
# dtype: object

# %%
y.dtypes
# Out:
# dtype('float64')

# %%
X.isna().sum()
# Out:
# density             0
# volatile_acidity    0
# chlorides           0
# is_red              0
# alcohol             0
# dtype: int64

# %%
#pip install auto-sklearn --user
# Out:
# Collecting auto-sklearn
#   Downloading auto-sklearn-0.14.7.tar.gz (6.4 MB)
#      |████████████████████████████████| 6.4 MB 13.9 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (60.9.3)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (4.1.1)
# Collecting distro
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.21.5)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.7.3)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.1.0)
# Collecting scikit-learn<0.25.0,>=0.24.0
#   Downloading scikit_learn-0.24.2-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
#      |████████████████████████████████| 24.9 MB 89.3 MB/s eta 0:00:01
# Collecting dask>=2021.12
#   Downloading dask-2022.6.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 90.5 MB/s eta 0:00:01
# Collecting distributed>=2012.12
#   Downloading distributed-2022.6.1-py3-none-any.whl (882 kB)
#      |████████████████████████████████| 882 kB 85.2 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      |████████████████████████████████| 701 kB 79.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=1.0 in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (1.3.5)
# Collecting liac-arff
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.8/site-packages (from auto-sklearn) (3.1.0)
# Collecting ConfigSpace<0.5,>=0.4.21
#   Downloading ConfigSpace-0.4.21-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 87.1 MB/s eta 0:00:01
# Collecting pynisher<0.7,>=0.6.3
#   Downloading pynisher-0.6.4.tar.gz (11 kB)
# Collecting pyrfr<0.9,>=0.8.1
#   Downloading pyrfr-0.8.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 99.5 MB/s eta 0:00:01
# Collecting smac<1.3,>=1.2
#   Downloading smac-1.2.tar.gz (260 kB)
#      |████████████████████████████████| 260 kB 100.6 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.8/site-packages (from ConfigSpace<0.5,>=0.4.21->auto-sklearn) (3.0.7)
# Collecting cython
#   Downloading Cython-0.29.30-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 106.3 MB/s eta 0:00:01
# Collecting cloudpickle>=1.1.1
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 113.5 MB/s eta 0:00:01
# Collecting toolz>=0.8.2
#   Downloading toolz-0.11.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 8.3 MB/s s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from dask>=2021.12->auto-sklearn) (21.3)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: click>=6.6 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (8.0.4)
# Collecting locket>=1.0.0
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: tornado>=6.0.3 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (6.1)
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting psutil>=5.0
#   Downloading psutil-5.9.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (284 kB)
#      |████████████████████████████████| 284 kB 105.7 MB/s eta 0:00:01
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (1.26.6)
# Collecting zict>=0.1.3
#   Downloading zict-2.2.0-py2.py3-none-any.whl (23 kB)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (322 kB)
#      |████████████████████████████████| 322 kB 111.1 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /home/ubuntu/.local/lib/python3.8/site-packages (from distributed>=2012.12->auto-sklearn) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=1.0->auto-sklearn) (2021.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->auto-sklearn) (1.16.0)
# Collecting emcee>=3.0.0
#   Downloading emcee-3.1.2-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 11.8 MB/s  eta 0:00:01
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/.local/lib/python3.8/site-packages (from jinja2->distributed>=2012.12->auto-sklearn) (2.1.0)
# Building wheels for collected packages: auto-sklearn, pynisher, smac, liac-arff
#   Building wheel for auto-sklearn (setup.py) ... done
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.14.7-py3-none-any.whl size=6602873 sha256=284683d14a04dac74f054a3eac8377004bcbcbca4d86af0ca75fdb7dc640cb4e
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/ad/44/ae/830c6d6190da34d4c9d8bdc1a26e2c84bd30b606181530955b
#   Building wheel for pynisher (setup.py) ... done
#   Created wheel for pynisher: filename=pynisher-0.6.4-py3-none-any.whl size=7043 sha256=f2be44a333b068e8745fd9d08628f8bc60e98194aeb1c2e78ff2cc724ab3e10d
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/a7/0b/c3/169e35bcd72f20d0d5e24c37dd2dff8282cc16c06df9762ff5
#   Building wheel for smac (setup.py) ... done
#   Created wheel for smac: filename=smac-1.2-py3-none-any.whl size=215922 sha256=67efe0436fdcf0c22f408c6a7d181a32b30c5fb7224cc5962e11be42d40c66cf
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/1c/0d/63/29515e546f52561bf5ff41e3968fe2c35afe4ae366be54b2c4
#   Building wheel for liac-arff (setup.py) ... done
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11733 sha256=4f1c57357e9cb097d3a4407afad92f2bfc74021239913c32e7aa1a897324c995
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/a2/de/68/bf3972de3ecb31e32bef59a7f4c75f0687a3674c476b347c14
# Successfully built auto-sklearn pynisher smac liac-arff
# Installing collected packages: toolz, locket, pyyaml, partd, heapdict, fsspec, cloudpickle, zict, tblib, sortedcontainers, psutil, msgpack, dask, cython, scikit-learn, pyrfr, pynisher, emcee, distributed, ConfigSpace, smac, liac-arff, distro, auto-sklearn
# Successfully installed ConfigSpace-0.4.21 auto-sklearn-0.14.7 cloudpickle-2.1.0 cython-0.29.30 dask-2022.6.1 distributed-2022.6.1 distro-1.7.0 emcee-3.1.2 fsspec-2022.5.0 heapdict-1.0.1 liac-arff-2.5.0 locket-1.0.0 msgpack-1.0.4 partd-1.2.0 psutil-5.9.1 pynisher-0.6.4 pyrfr-0.8.3 pyyaml-6.0 scikit-learn-0.24.2 smac-1.2 sortedcontainers-2.4.0 tblib-1.7.0 toolz-0.11.2 zict-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import autosklearn

# %%
from autosklearn import automl

# %%
# %%time
aml = automl.AutoMLRegressor(time_left_for_this_task =30, per_run_time_limit=30)
# aml.fit(X_train,y_train)
# Out:
# CPU times: user 37 µs, sys: 7 µs, total: 44 µs
# Wall time: 48.9 µs

# %%
gbr = GradientBoostingRegressor(loss='ls',learning_rate = 0.15, n_estimators=75, criterion = 'mse')

gbr.fit(X_train,y_train)
# Out:
# /opt/conda/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:471: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/ensemble/_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/sklearn/tree/_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# GradientBoostingRegressor(criterion='mse', learning_rate=0.15, loss='ls',
#                           n_estimators=75)

# %%
from sklearn.metrics import mean_squared_error, r2_score
preds = gbr.predict(X_test)
print("R2 Score: ", round(r2_score(y_test, preds),3))
print("MSE: ", round(mean_squared_error(y_test, preds),3))
# Out:
# R2 Score:  0.226
# MSE:  0.926

# %%
round(r2_score(y_test, preds),3)
# Out:
# 0.226

# %%
from sklearn.ensemble import AdaBoostRegressor

adb = AdaBoostRegressor()
adb.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
preds = adb.predict(X_test)
print("R2 Score: ", round(r2_score(y_test, preds),3))
print("MSE: ", round(mean_squared_error(y_test, preds),3))
# Out:
# R2 Score:  0.177
# MSE:  0.985

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor()
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
preds = rfr.predict(X_test)
print("R2 Score: ", round(r2_score(y_test, preds),3))
print("MSE: ", round(mean_squared_error(y_test, preds),3))
# Out:
# R2 Score:  0.187
# MSE:  0.972

# %%
import json
with open('dominostats.json', 'w') as f:
    f.write(json.dumps({"R2": round(r2_score(y_test, preds),3),
                       "MSE": round(mean_squared_error(y_test,preds),3)}))

# %%
import json
with open('dominostats.json', 'w') as f:
    f.write(json.dumps({"R^2": 0.99, "p-value": 0.05, "sse": 10.49}))

# %%
results = pd.DataFrame({'Actuals':y_test, 'Predictions':preds})

# %%
results
# Out:
#       Actuals  Predictions
# 1143     5.65     5.911420
# 2708     6.84     5.827700
# 4943     3.64     5.929983
# 4194     6.30     5.958100
# 5956     6.51     6.088033
# ...       ...          ...
# 4654     6.51     6.957720
# 2155     4.25     5.233880
# 5022     5.05     4.793333
# 6003     5.95     6.217225
# 1047     4.60     5.932550
#
# [1422 rows x 2 columns]

# %%
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.title('Sklearn Actuals vs Predictions Scatter Plot')
sns.regplot( 
    data=results,
    x = 'Actuals',
    y = 'Predictions',
    order = 2)
plt.savefig('/mnt/artifacts/results/sklearn_actual_v_pred_scatter.png')

# %%
fig2, ax2 = plt.subplots(figsize=(10,6))
plt.title('Sklearn Actuals vs Predictions Histogram')
plt.xlabel('Quality')
sns.histplot(results, bins=6, multiple = 'dodge', palette = 'coolwarm')
plt.savefig('/mnt/artifacts/results/sklearn_actual_v_pred_hist.png')

# %%
import pickle 

# save best model
file = '/mnt/artifacts/results/sklearn_gbm.pkl'
pickle.dump(gbr, open(file, 'wb'))

# %%
X.head()
# Out:
#    density  volatile_acidity  chlorides  is_red  alcohol
# 0   1.0010              0.27      0.045       0      8.8
# 1   0.9940              0.30      0.049       0      9.5
# 2   0.9951              0.28      0.050       0     10.1
# 3   0.9956              0.23      0.058       0      9.9
# 4   0.9956              0.23      0.058       0      9.9
